# %% [markdown]
# <a href="https://colab.research.google.com/github/Melodial-tech/uas-brian/blob/main/uas_brian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
#sebaran 13 pembangkit listrik di indonesia
#beserta kapasitas total
x = np.array(["Sarulla","Ulubelu","Salak","Patuha"])
y = np.array([330,220,377,227])
c =["blue","green","red","yellow"]

plt.title("PLTP dengan kapasitas total terbesar di Indonesia")
plt.xlabel("Nama PLTP")
plt.ylabel("kapasital total (MW)")
plt.bar(x,y,color = c)
plt.show()
